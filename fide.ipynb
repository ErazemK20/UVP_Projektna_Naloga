# %% [markdown]
# Poganjanje glavnega programa fide.py

# %%
import fide
# Out:
# /Users/matej/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Zajemam podatke za FIDE ID: 14629500
# 2426 Domen Tisaj , roj. 2002 , Mednarodni mojster
# 2162 Andraz Gregoric , roj. 2007 ,
# 2114 Svit Siraj , roj. 2006 ,
# 2102 Luka Vaupot , roj. 2005 ,
# 2028 Gasper Tompa , roj. 1979 ,
# 1985   , roj. 1962 ,
# 1965 Denis Vah , roj. 2003 ,
# 1921 Aljaz Susin , roj. 1997 ,
# 1915 Gasper Stukelj , roj. 1993 ,
# 1905 Pia Rozmanec , roj. 2006 ,
# 1873 Hubert Ipavic , roj. 1942 ,
# 1855 Karel Zajdela , roj. 1963 ,
# 1848 Damjan Gorse , roj. 1974 ,
# 1841 Ivan Podlesnik , roj. 1971 ,
# 1823 Anze Novak , roj. 1989 ,
# 1822 Simona Novak , roj. 1962 ,
# 1792 Alojz Gracner , roj. 1942 ,
# 1788 Martin Reseta , roj. 1991 ,
# 1786 Ivan Susin , roj. 1964 ,
# ...

# %% [markdown]
# Uvoz modula fide_graf za graficno analizo

# %%
import fide_graf

# %% [markdown]
# Risanje histograma ter raztresenega diagrama za podatke iz datoteke seznam.txt ustvarjene z
# glavnim programom

# %%
fide_graf.graf("seznam.txt")

# %% [markdown]
# Vnovicen uvoz v primeru spreminjanja izvorne datoteke

# %%
import importlib

# %%
importlib.reload(fide_graf)
# Out:
# <module 'fide_graf' from '/Users/matej/Projects/Zajem/fide_graf.py'>

# %%
fide_graf.graf("seznam.txt")

# %%
import fide_graf
